# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample com os dados dos participantes da prova do Enem 2019. O arquivo contém informações sobre as notas dos participantes, além de informações socioeconômicas
fonte = "https://raw.githubusercontent.com/alura-cursos/imersao-dados-2-2020/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv"

dados = pd.read_csv(fonte)
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001004661    2019                  1506138  ...    A     B    B
# 1  190001004674    2019                  1504208  ...    A     A    B
# 2  190001004722    2019                  1501402  ...    A     A    B
# 3  190001004735    2019                  1507300  ...    A     A    B
# 4  190001004776    2019                  1500800  ...    A     A    B
#
# [5 rows x 136 columns]

# %%
# Shape é um método parar retornar uma tupla com a dimensão do dataframe
dados.shape
dados['CO_MUNICIPIO_ESC']
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#             ...
# 127375    3142700.0
# 127376    2902807.0
# 127377          NaN
# 127378          NaN
# 127379          NaN
# Name: CO_MUNICIPIO_ESC, Length: 127380, dtype: float64

# %%
# O método values retorna um array com valores do DataFrame
dados.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        'TP_NACIONALIDADE', 'CO_MUNICIPIO_NASCIMENTO',
#        'NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA',
#        'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL',
#        'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA',
#        'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE',
#        'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR',
# ...

# %%
# Usando uma lista das colunas como parâmetro no dataframe , ele retorna uma matriz com os valores escolhidos. 
dados[["IN_BRAILLE", "Q008"]]
# Out:
#         IN_BRAILLE Q008
# 0                0    C
# 1                0    B
# 2                0    B
# 3                0    B
# 4                0    B
# ...            ...  ...
# 127375           0    C
# 127376           0    B
# 127377           0    B
# 127378           0    B
# 127379           0    B
#
# [127380 rows x 2 columns]

# %%
# Retornar uma série contendo valores não repetidos
dados["NU_IDADE"].value_counts()
# Out:
# 18    21452
# 17    21256
# 19    14418
# 20    10413
# 16     7830
#       ...
# 75        2
# 73        2
# 82        1
# 77        1
# 76        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
# Ordenar os dados obtidos
dados["NU_IDADE"].value_counts().sort_index()
# Out:
# 13        4
# 14      141
# 15     2009
# 16     7830
# 17    21256
#       ...
# 73        2
# 75        2
# 76        1
# 77        1
# 82        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
# Filtrar os dados dos treineiros, ordenando por idade
dados.query("IN_TREINEIRO == 1")["NU_IDADE"].value_counts().sort_index()
# Out:
# 14      64
# 15    1927
# 16    7142
# 17    4901
# 18     858
# 19     228
# 20      83
# 21      44
# 22      30
# 23      21
# 24      13
# 25       8
# 26      13
# 27       9
# 28       6
# 29      10
# 30       4
# 31       4
# 32       2
# 33       1
# 34       3
# 35       2
# 36       2
# 37       1
# 38       4
# 39       2
# 40       4
# 41       1
# 42       4
# 44       2
# 45       1
# 46       2
# 47       1
# 48       1
# 51       1
# 55       1
# 62       1
# Name: NU_IDADE, dtype: int64

# %%
# Histograma com as notas em Linguagens e códigos
dados["NU_NOTA_LC"].hist(bins = 10, figsize = (5, 4))

# %%
# Média da prova de linguagens e códigos
dados["NU_NOTA_LC"].mean()
# Out:
# 520.4639280723744

# %%
dados.query("IN_TREINEIRO == 0")["NU_IDADE"].hist(bins = 20)

# %%
provas = [ "NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_LC",
       "NU_NOTA_MT", "NU_NOTA_REDACAO"]       
dados[provas].describe()
# Out:
#          NU_NOTA_CN    NU_NOTA_CH    NU_NOTA_LC    NU_NOTA_MT  NU_NOTA_REDACAO
# count  92758.000000  98043.000000  98043.000000  92758.000000     98043.000000
# mean     477.964015    507.365912    520.463928    523.555206       571.570025
# std       76.296099     82.972839     64.556578    109.416939       188.076455
# min        0.000000      0.000000      0.000000      0.000000         0.000000
# 25%      418.000000    447.900000    483.700000    435.300000       480.000000
# 50%      470.200000    510.900000    526.100000    501.600000       580.000000
# 75%      533.300000    567.100000    565.100000    598.200000       680.000000
# max      797.300000    809.400000    801.700000    985.000000      1000.000000

# %%
dados["NU_NOTA_CN"].quantile(0.9)
# Out:
# 582.2

# %%
dados["NU_NOTA_CN"].plot.box(figsize = (8,6))

# %%
dados[provas].boxplot(grid=True, figsize = (8, 6))

# %%
dados.query("NU_IDADE <= 18")["TP_SEXO"].value_counts()
# Out:
# F    32211
# M    20481
# Name: TP_SEXO, dtype: int64

# %%
menores = dados.query("NU_IDADE <= 18")
# Proporção entre homens e mulheres menores de idade realizando a prova
menores["TP_SEXO"].value_counts().plot.pie()
plt.legend(["Feminino", "Masculino"])

# %%
import seaborn as sns

# Boxplot das notas em Ciências da Natureza ordenadas pela renda
plt.figure(figsize = (10,8))
renda_ordenada = dados["Q006"].unique()
renda_ordenada.sort()
sns.boxplot(x="Q006", y="NU_NOTA_CN", data=dados, order=renda_ordenada)
plt.title("Boxplot das notas")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas')

# %%
dados["NU_NOTA_TOTAL"] = dados[provas].sum(axis=1)
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B        2288.9
# 1  190001004674    2019                  1504208  ...    A     B        1184.6
# 2  190001004722    2019                  1501402  ...    A     B        2350.5
# 3  190001004735    2019                  1507300  ...    A     B        2555.7
# 4  190001004776    2019                  1500800  ...    A     B        2803.5
#
# [5 rows x 137 columns]

# %%
# Boxplot do somatório das notas nas provas ordenadas pela renda. Nota-se uma correlação entre aumento da renda e a nota
plt.figure(figsize = (10,8))
sns.boxplot(x="Q006", y="NU_NOTA_TOTAL", data=dados, order=renda_ordenada)
plt.title("Boxplot das notas")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas')

# %%
sns.displot(dados, x = "NU_NOTA_TOTAL", kind='hist',)

# %%
provas = [ "NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_LC",
       "NU_NOTA_MT", "NU_NOTA_REDACAO"]
provas.append("NU_NOTA_TOTAL")
dados[provas].query("NU_NOTA_TOTAL == 0")
# Out:
#         NU_NOTA_CN  NU_NOTA_CH  ...  NU_NOTA_REDACAO  NU_NOTA_TOTAL
# 10             NaN         NaN  ...              NaN            0.0
# 11             NaN         NaN  ...              NaN            0.0
# 26             NaN         NaN  ...              NaN            0.0
# 38             NaN         NaN  ...              NaN            0.0
# 40             NaN         NaN  ...              NaN            0.0
# ...            ...         ...  ...              ...            ...
# 127351         NaN         NaN  ...              NaN            0.0
# 127365         NaN         NaN  ...              NaN            0.0
# 127366         NaN         NaN  ...              NaN            0.0
# 127368         NaN         NaN  ...              NaN            0.0
# 127374         NaN         NaN  ...              NaN            0.0
#
# [29162 rows x 6 columns]

# %%
dados_sem_nota_zero = dados.query("NU_NOTA_TOTAL != 0")
dados_sem_nota_zero.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B        2288.9
# 1  190001004674    2019                  1504208  ...    A     B        1184.6
# 2  190001004722    2019                  1501402  ...    A     B        2350.5
# 3  190001004735    2019                  1507300  ...    A     B        2555.7
# 4  190001004776    2019                  1500800  ...    A     B        2803.5
#
# [5 rows x 137 columns]

# %%
# Boxplot das notas com o parâmetro hue="IN_TREINEIRO". Este parâmetro serve para incluir mais uma informação no boxplot, nesse caso, ser treineiro ou não
plt.figure(figsize = (12,10))
sns.boxplot(x = "Q006", y = "NU_NOTA_CN", data = dados_sem_nota_zero, hue = "IN_TREINEIRO", order=renda_ordenada)
plt.title("Boxplot das notas sem nota zero")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas sem nota zero')

# %%
# O gráfico anterior usando, dessa vez, ter ou não internet como parâmetro hue. 
plt.figure(figsize = (12,10))
sns.boxplot(x = "Q006", y = "NU_NOTA_CN", data = dados_sem_nota_zero, hue = "Q025", order=renda_ordenada)
plt.title("Boxplot das notas sem nota zero")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas sem nota zero')

# %%
sns.histplot(dados_sem_nota_zero, x = "NU_NOTA_TOTAL")

# %%
sns.histplot(dados_sem_nota_zero, x = "NU_NOTA_LC")

# %%
plt.figure(figsize = (10,8))
sns.histplot(dados_sem_nota_zero, x = "NU_NOTA_TOTAL", hue="Q025", kde=True, stat="probability")

# %%
plt.figure(figsize = (10,8))
sns.histplot(dados_sem_nota_zero, x = "NU_NOTA_TOTAL", hue="Q025", kde=True, stat="probability", cumulative=True)

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=dados_sem_nota_zero, x="NU_NOTA_MT", y="NU_NOTA_LC")

# %%
# Correlação ir bem em Matemática e Ciências da Natureza
plt.figure(figsize=(10,8))
sns.scatterplot(data=dados_sem_nota_zero, x="NU_NOTA_MT", y="NU_NOTA_CN")

# %%
# Correlação ir bem em Linguagens e Ciências humanas
plt.figure(figsize=(10,8))
sns.scatterplot(data=dados_sem_nota_zero, x="NU_NOTA_MT", y="NU_NOTA_CH")

# %%
# Pelo gráfico, há uma correlação maior entre ir bem em Matemática/Ciências da Natureza e Línguagens e Códigos/Ciências Humanas do que Matemática/Linguagens e Códigos

# %%
sns.pairplot(dados_sem_nota_zero[provas])

# %%
correlaçao = dados_sem_nota_zero[provas].corr()
correlaçao
# Out:
#                  NU_NOTA_CN  NU_NOTA_CH  ...  NU_NOTA_REDACAO  NU_NOTA_TOTAL
# NU_NOTA_CN         1.000000    0.668979  ...         0.504740       0.785600
# NU_NOTA_CH         0.668979    1.000000  ...         0.528338       0.735534
# NU_NOTA_LC         0.641624    0.744170  ...         0.535797       0.711686
# NU_NOTA_MT         0.649527    0.610332  ...         0.493046       0.790051
# NU_NOTA_REDACAO    0.504740    0.528338  ...         1.000000       0.783647
# NU_NOTA_TOTAL      0.785600    0.735534  ...         0.783647       1.000000
#
# [6 rows x 6 columns]

# %%
# Plotando um gráfico 'striplot' com uma das variáves sendo categórica(Q006 a renda familiar). Fica 
sns.stripplot(x='Q006', y='NU_NOTA_TOTAL', data=dados_sem_nota_zero)

# %%
sns.heatmap(correlaçao, cmap="Blues", annot=True)

# %%
# Aula 04 - Machine Learning
provas_entrada = ["NU_NOTA_CH", "NU_NOTA_LC", "NU_NOTA_REDACAO"]
provas_saida = "NU_NOTA_MT"
dados_sem_notas = dados_sem_nota_zero[provas].dropna()

notas_entrada = dados_sem_notas[provas_entrada]
notas_saida = dados_sem_notas[provas_saida]

# %%
x = notas_entrada
y = notas_saida

from sklearn.model_selection import train_test_split

SEED = 1729


x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.25, random_state=SEED)

x_treino.head()

x_treino.shape
# Out:
# (69402, 3)

# %%
from sklearn.svm import LinearSVR

modelo = LinearSVR(random_state = SEED)
modelo.fit(x_treino, y_treino)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVR(C=1.0, dual=True, epsilon=0.0, fit_intercept=True,
#           intercept_scaling=1.0, loss='epsilon_insensitive', max_iter=1000,
#           random_state=1729, tol=0.0001, verbose=0)

# %%
prediçao = modelo.predict(x_teste)

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=prediçao, y=y_teste)
plt.xlim(-50,1050)
plt.ylim(-50, 1050)
# Out:
# (-50.0, 1050.0)

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=y_teste, y=y_teste - prediçao)
plt.xlim(-50,1050)
plt.ylim(-50, 1050)
# Out:
# (-50.0, 1050.0)

# %%
resultados = pd.DataFrame()
resultados["Real"] = y_teste
resultados["Previsão"] = prediçao
resultados["Diferença"] = resultados["Real"] - resultados["Previsão"]
resultados["Quadrado da Diferença"] = (resultados["Real"] - resultados["Previsão"])**2

resultados
# Out:
#          Real    Previsão   Diferença  Quadrado da Diferença
# 111565  500.7  457.228516   43.471484            1889.769882
# 115286  582.5  507.323554   75.176446            5651.497992
# 65932   490.3  598.847793 -108.547793           11782.623381
# 51046   678.1  533.664139  144.435861           20861.717955
# 84536   451.2  451.082205    0.117795               0.013876
# ...       ...         ...         ...                    ...
# 79576   695.7  551.622652  144.077348           20758.282114
# 112253  382.6  398.645513  -16.045513             257.458500
# 57936   790.3  555.554349  234.745651           55105.520717
# 108874  444.1  430.690302   13.409698             179.819999
# 104233  516.1  445.858753   70.241247            4933.832710
#
# [23135 rows x 4 columns]

# %%
resultados["Quadrado da Diferença"].mean()
# Out:
# 9946.856075741807

# %%
resultados["Quadrado da Diferença"].mean()**(1/2)
# Out:
# 99.73392640291371

# %%
from sklearn.dummy import DummyRegressor

modelo_dummy = DummyRegressor()
modelo_dummy.fit(x_treino, y_treino)
dummy_prediçoes = modelo_dummy.predict(x_teste)

from sklearn.metrics import mean_squared_error

mean_squared_error(y_teste, dummy_prediçoes)
# Out:
# 11896.703944271225

# %%
# Aula 05

from sklearn.svm import LinearSVR

modelo = LinearSVR(random_state=SEED)
modelo.fit(x_treino, y_treino)
predicoes_matematica = modelo.predict(x_teste)
mean_squared_error(y_teste, prediçao)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 9946.856075741873

# %%
# Modelo decision tree(pesquisar)
from sklearn.tree import DecisionTreeRegressor



x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.25)
modelo_arvore = DecisionTreeRegressor(max_depth = 3)
modelo_arvore.fit(x_treino, y_treino)
predicoes_arvore =  modelo_arvore.predict(x_teste) 
mean_squared_error(y_teste, predicoes_arvore)
# Out:
# 6409.803135139094

# %%
# Objetivo comparar modelos

from sklearn.model_selection import cross_validate

modelo_arvore = DecisionTreeRegressor(max_depth = 2)
resultados = cross_validate(modelo_arvore, x, y, cv= 10, scoring="neg_mean_squared_error")
media = (resultados["test_score"]*-1).mean()
media
# Out:
# 6827.306656352067

# %%
#  Calcular o intervalo de confiança usando o desvio padrão(usando uma definição não muito precisa de intervalo de confiança)
from sklearn.model_selection import cross_validate

modelo_arvore = DecisionTreeRegressor(max_depth=2)
resultados = cross_validate(modelo_arvore, x, y, cv= 10, scoring="neg_mean_squared_error")
media = (resultados["test_score"]*-1).mean()
desvio_padrao = (resultados["test_score"]*-1).std()
lim_inferior = media - (2*desvio_padrao)
lim_superior = media + (2*desvio_padrao)

print(f"Intervalo de confiança {lim_inferior} - {lim_superior}")
# Out:
# Intervalo de confiança 6248.761607475397 - 7405.851705228739

# %%
# Função para calcular o intervalo de confiança
def calcula_mse(resultados):
    media = (resultados["test_score"]*-1).mean()
    desvio_padrao = (resultados["test_score"]*-1).std()
    lim_inferior = media - (2*desvio_padrao)
    lim_superior = media + (2*desvio_padrao)
    print(f"Intervalo de confiança {lim_inferior} - {lim_superior}")

# %%
 from sklearn.model_selection import cross_validate
# Importar o KFold para embaralhar os dados para evitar um viés na amostra
from sklearn.model_selection import KFold
import numpy as np

SEED= 1232
np.random.seed(SEED)



partes = KFold(n_splits = 10, shuffle=True)
modelo_arvore = DecisionTreeRegressor(max_depth=3)
resultados = cross_validate(modelo_arvore, x, y, cv= partes, scoring="neg_mean_squared_error")
calcula_mse(resultados)
# Out:
# Intervalo de confiança 6220.326642284236 - 6642.480236924518

# %%
def regressor_arvore(nivel):
    SEED= 1232
    np.random.seed(SEED)
    partes = KFold(n_splits = 10, shuffle=True)
    modelo_arvore = DecisionTreeRegressor(max_depth=nivel)
    resultados = cross_validate(modelo_arvore, x, y, cv= partes, scoring="neg_mean_squared_error", return_train_score=True)
    print(f"Treino = {(resultados['train_score']*-1).mean()}|Teste = {(resultados['test_score']*-1).mean()}")

regressor_arvore(4)
# Out:
# Treino = 6133.640032930441|Teste = 6187.172563449341

# %%
# Overfit - dados "decoraram" os valores, porém o modelo não funcionará bem para um caso mais geral
for i in range(1,21):
    regressor_arvore(i)
# Out:
# Treino = 8040.1890238801325|Teste = 8063.803891020839
# Treino = 6795.017424540182|Teste = 6833.094177524074
# Treino = 6390.378133362772|Teste = 6431.403439604377
# Treino = 6133.640032930441|Teste = 6187.172563449341
# Treino = 5977.013856774012|Teste = 6053.544085989619
# Treino = 5876.616472222384|Teste = 5972.872506600253
# Treino = 5802.175506997404|Teste = 5946.841345881366
# Treino = 5728.173367174485|Teste = 5984.739576649215
# Treino = 5630.396455309414|Teste = 6059.564827306407
# Treino = 5491.185161753759|Teste = 6190.364591662788
# Treino = 5305.153016879929|Teste = 6388.089844731424
# Treino = 5067.610897591065|Teste = 6648.9637278384935
# Treino = 4779.397222036039|Teste = 6965.780632787918
# Treino = 4450.356632507811|Teste = 7319.150595970919
# Treino = 4084.146562252458|Teste = 7724.357623969389
# Treino = 3694.6280514555897|Teste = 8122.097044723747
# Treino = 3296.420462873596|Teste = 8549.038487462283
# Treino = 2901.363772113773|Teste = 8982.945254059832
# ...
